# %%
from tkinter import *
import sign_to_text_speech as sp
import text_to_sign as ts

import os
import math
import numpy as np
import matplotlib.pyplot as plt

import PIL
from PIL import Image, ImageFilter

from PIL import ImageTk, Image

#from scrollimage import ScrollableImage
from tkscrolledframe import ScrolledFrame
from tkinter import ttk
from tkinter import messagebox
from tkinter import filedialog



window = Tk()

window.title("SIGN LANGUAGE TRANSLATOR FOR SPEECH- AND HEARING- IMPAIRED")
bg = PhotoImage(file = "p1.png")
  
# Show image using label
label1 = Label( window, image = bg)
label1.place(x = 0, y = 0)
#window.geometry('1080x900')
#window.config(bg='grey80')
#img = PhotoImage(file='p.png',master=window)
#lab = Label(window,image=img)

window.title("SIGN LANGUAGE TRANSLATOR FOR SPEECH- AND HEARING- IMPAIRED")
 
lbl = Label(window, text="SIGN LANGUAGE TRANSLATOR FOR SPEECH- AND HEARING- IMPAIRED", font= 'Algerian 15 bold')
lbl1 = Label(window, text="SELECT MODE ::", font= 'Arial 10 bold')
#lbl.place(relx=0.5, rely=0.5, anchor=CENTER)

lbl.grid(column=0, row=0)
lbl = Label(window)
 
lbl.grid(column=0, row=1)
lbl = Label(window, text="SELECT MODE ::", font= 'Algerian 10 bold')
 
lbl.grid(column=0, row=2)
lbl = Label(window, text="")
 
lbl.grid(column=0, row=3)
lbl = Label(window, text="")
 
lbl.grid(column=0, row=4)

#txt.delete(0,'end')
#res = "Welcome" 
#txt.insert(0,res)
#txt.delete?
#combo = Combobox(window)

#combo['values']= (1, 2, 3, 4, 5, "Text")

#combo.current(1) #set the selected item
#combo.grid(column=2,row=0)

#from PIL import Image, ImageTk
#We use Image and ImageTk from the Python Imaging Library (PIL) module. 
from tkinter import Tk, BOTH
from tkinter.ttk import Frame, Label, Style

def sign_text():
    sp.check()
def text_sign():
    #from PIL import ImageTk, Image
    window = Tk()
 
    window.title("TEXT/SPEECH TO SIGN LANGUAGE")
        
    lbl = Label(window, text="SIGN LANGUAGE TRANSLATOR", font= 'Algerian 16 bold')

    lbl.grid(column=1, row=1)
    txt = Entry(window,width=40)#, state='disabled'
    txt.grid(column=3, row=2)
    #txt.delete(0,'end')
    #res = "Welcome" 
    #txt.insert(0,res)
    #txt.delete?
    #combo = Combobox(window)

    #combo['values']= (1, 2, 3, 4, 5, "Text")

    #combo.current(1) #set the selected item
    #combo.grid(column=2,row=0)
    
    def clicked():
        #cm=combo.get()
        res = txt.get()
        #txt.insert(0,"")
        #txt.delete(0,'END')
        ts.main(res)
        #img = ImageTk.PhotoImage(Image.open("H:/code check/FinalProject_SignLang(DL)/aa.jpg"))
        #print('...',img)
        #llabel = Label(window1, image = img,height=200, width=200)
        #rot = Image.open("H:/code check/FinalProject_SignLang(DL)/aa.jpg")
        #rotunda = ImageTk.PhotoImage(rot)
        #label2 = Label(window, image=rotunda)
        #label2.image = rotunda
        #label2.place(x=40, y=160)

        #label.grid(column=1, row=3)
    def clicked1():
        import speech_recognition as sr
        import pyaudio


        # Initialize the recognizer  
        r = sr.Recognizer()

        # use the microphone as source for input. 
        with sr.Microphone() as source:
            print("Say something")
            audio = r.listen(source)
            print("Time Over..")

        try:
            print("Text:"+r.recognize_google(audio))
            f = open("speech/speech.txt","w")
            print(r.recognize_google(audio), file = f)
            f.close()
            f=open("speech/speech.txt",'r')
            res=f.read()
            f.close()
            ts.main(res)
            #rot = Image.open("H:/code check/FinalProject_SignLang(DL)/aa.jpg")
            #rotunda = ImageTk.PhotoImage(rot)
            #label2 = Label(self, image=rotunda)
            #label2.image = rotunda
            #label2.place(x=40, y=160)

            #label2.grid(column=1, row=3)
        except:
            pass
       
    btn = Button(window, text="Submit", bg="black", fg="white",command=clicked)
    btn.grid(column=4, row=9)
    btn = Button(window, text="Speak", bg="LightGoldenrod4", fg="white",command=clicked1)
    btn.grid(column=2, row=9)
    window.geometry('1080x500')
    window.mainloop()
    
btn = Button(window, text="Sign To Text/Speech", bg="LightGoldenrod4", fg="white",command=sign_text)
btn.grid(column=0, row=6)
lbl = Label(window) 
lbl.grid(column=10, row=6)
btn = Button(window, text="Text/Speech To Sign", bg="LightGoldenrod4", fg="white",command=text_sign)
btn.grid(column=1, row=6)


window.geometry('1080x400')
window.mainloop()
# Out:
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# THANK YOU
# res THANK YOU
# HELLO
# res HELLO
# HELLO
# res HELLO
# HELLO
# res HELLO
# HELLO
# res HELLO
# HELLO
# res HELLO
# HELLO
# res HELLO
# HELLO
# res HELLO
# HELLO
# res HELLO
# HELLO
# res HELLO
# HELLO
# res HELLO
# GOODBYE
# res GOODBYE
# GOODBYE
# res GOODBYE
# GOODBYE
# res GOODBYE
# GOODBYE
# res GOODBYE
# GOODBYE
# res GOODBYE
# ...

# %%
'''
click 's' when "speak"
click 'c' when text from sign
click 'q' to close
'''
